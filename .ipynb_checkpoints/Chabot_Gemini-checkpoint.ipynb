# %%
import os
import google.generativeai as genai
from IPython.display import display, Markdown
import PIL.Image

api_key = os.getenv('GEMINI_API_KEY')
if not api_key:
    raise ValueError("API key not found. Please set the GEMINI_API_KEY environment variable.")


model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Write an essay on Corporate Life make sure Starting , body and conclusion should be great.write in Hindi")
display(Markdown(response.text))
# Out:
# ## कॉर्पोरेट जीवन: एक चुनौतीपूर्ण यात्रा
#
# कॉर्पोरेट जीवन, एक ऐसा क्षेत्र जहाँ व्यक्ति अपनी प्रतिभा और क्षमता को निखारने के लिए कदम रखते हैं। यह क्षेत्र चुनौतियों से भरा है, लेकिन साथ ही,  सफलता और संतुष्टि के अनेक अवसर भी प्रदान करता है।
#
# एक कॉर्पोरेट कर्मचारी के जीवन में अनेक चुनौतियाँ होती हैं।  प्रतिस्पर्धा का उच्च स्तर, समय की कमी, काम का दबाव, और निरंतर सीखने की आवश्यकता, सभी इन चुनौतियों का हिस्सा हैं।  इस जीवन में सफलता के लिए कड़ी मेहनत, समर्पण और लचीलापन की आवश्यकता होती है।  साथ ही,  संचार कौशल, टीम वर्क, और नेतृत्व क्षमता का विकास भी महत्वपूर्ण होता है।
#
# इस चुनौतीपूर्ण यात्रा के बावजूद,  कॉर्पोरेट जीवन व्यक्ति को अनेक अवसर भी प्रदान करता है।   आर्थिक स्थिरता,  करियर प्रगति,  और  नए अनुभवों का अवसर,   इन अवसरों में शामिल हैं।  कॉर्पोरेट जीवन  व्यक्ति को  विभिन्न लोगों के साथ काम करने का अनुभव प्रदान करता है, जिससे  उसके संचार कौशल और  सामाजिक कौशल का विकास होता है।   इसके अलावा,  कॉर्पोरेट  जीवन  व्यक्ति को  नई तकनीकों और  ज्ञान  से  अपना परिचय कराता है,   जिससे   वह   अपने  करियर   में    आगे   बढ़ सकता है।
#
# निष्कर्ष में,  कॉर्पोरेट जीवन  एक  चुनौतीपूर्ण  लेकिन   फायदेमंद  यात्रा है।   यह  जीवन   व्यक्ति   को   अपनी   क्षमता   को  निखारने   का   अवसर   प्रदान   करता   है।   हालांकि,   इस  यात्रा   में   सफलता   के   लिए   कड़ी   मेहनत,   समर्पण   और   लचीलापन   की   आवश्यकता   होती   है।   कॉर्पोरेट  जीवन   के   चुनौतियों   का   सामना   करने   और   इसके   अवसरों   का   लाभ   उठाने   से   व्यक्ति   अपने   करियर   में   सफलता   प्राप्त   कर   सकता   है।

# %%
# %%time
image=PIL.Image.open('/home/abhishek.anand/groom-3452735_640.jpg')
display(image)
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(image)
display(Markdown(response.text))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=427x640 at 0x75E316B8FB80>
# The image shows a man in traditional Indian clothing riding a horse. He is likely getting married as he is wearing a turban and a lot of jewelry. The horse is also decorated with colorful fabrics and jewels. The man looks very happy and proud. This is a common sight in India at weddings, as it is a tradition for the groom to ride a horse to the ceremony. The image captures the beauty and richness of Indian culture.
# CPU times: user 85.1 ms, sys: 0 ns, total: 85.1 ms
# Wall time: 1.65 s

# %%
import os
import google.generativeai as genai
from IPython.display import display, Markdown

# Initialize the model
model = genai.GenerativeModel('gemini-pro')
chat = model.start_chat(history=[])

try:
    while True:
        user_message = input("You (type 'exit' to stop or press Ctrl+C): ")
        
        if user_message.lower() == 'exit':
            print("Exiting the chat. Goodbye!")
            break  
        
        # Send the user message and get the model's response
        response = chat.send_message(user_message)
        
        # Display user input
        print("\n" + "="*40)
        display(Markdown(f"**You:** {user_message}"))
        
        # Display model's response in a formatted manner
        display(Markdown(f"**Model:** {response.text}"))
        print("="*40 + "\n")  # Separator for clarity

except KeyboardInterrupt:
    print("\nExiting the chat. Goodbye!")
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# You (type 'exit' to stop):  exit
# Exiting the chat. Goodbye!
